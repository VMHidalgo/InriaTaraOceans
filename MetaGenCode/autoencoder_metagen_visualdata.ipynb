# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv("/home/vmh/vmhdocs/Research/Inria/Anl/MetaGenAutoencoder/Data/KO_metaG.norm.txt",sep="\t")
print(df.shape)
df.head(5)
# Out:
# (180, 9026)
#         Unnamed: 0      unknown    K00002    K00003    K00004    K00005  \
# 0  TARA_X000000368  1066.943519  0.007901  0.720651  0.007374  0.065015
# 1  TARA_Y200000002  1005.294640  0.004569  0.791990  0.001405  0.137334
# 2  TARA_A200000159  1445.388792  0.003585  0.626508  0.005761  0.094833
# 3  TARA_A200000113   834.386113  0.003152  0.701588  0.000379  0.046740
# 4  TARA_X000001036  1071.164118  0.004687  0.710648  0.010831  0.037637
#
#      K00006    K00007    K00008    K00009  ...  K22754    K22755    K22757  \
# 0  0.006160  0.003610  0.022136  0.063239  ...     0.0  0.000239  0.117896
# 1  0.000713  0.000821  0.028764  0.027357  ...     0.0  0.000096  0.066136
# 2  0.001693  0.000240  0.024149  0.049252  ...     0.0  0.000407  0.083504
# 3  0.000000  0.000311  0.020406  0.035872  ...     0.0  0.000000  0.091899
# 4  0.002630  0.000941  0.057089  0.058175  ...     0.0  0.000271  0.119328
#
#      K22761    K22762    K22763    K22764    K22766  K22769    K22770
# 0  0.002513  0.002100  0.000817  0.000037  0.002555     0.0  0.000000
# 1  0.000266  0.000262  0.000694  0.000083  0.000455     0.0  0.000010
# 2  0.001305  0.000945  0.000932  0.000000  0.001044     0.0  0.000000
# 3  0.000000  0.000000  0.000142  0.000000  0.000024     0.0  0.000007
# 4  0.001846  0.001367  0.000796  0.000099  0.001466     0.0  0.000000
#
# [5 rows x 9026 columns]

# %% [markdown]
# # Plot histogram for each column

# %%
hist = df.iloc[:,0:20].hist(bins=100,figsize=(10,12))
