# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# # Load the dataset and select the columns

# %%
df = pd.read_csv("/home/vmh/vmhdocs/Research/Inria/Anl/MotifsDataAutoencoder/Data/3_46cols_EnvFeatures173samples_plus_3202EC_V2_original.csv",sep=",")
df.head(5)
print(len(df.columns))
tfms = df.iloc[:,46:-1]
print(len(tfms.columns))
# Out:
# 3248
# (173, 3248)
# 3201
# (173, 3201)

# %% [markdown]
# # Plot histogram for each column

# %%
plt.figure(figsize=(10,120))
cols = tfms.columns[0:50]
for i in range(len(cols)):
    plt.subplot(len(cols),1,i+1)
    plt.hist(tfms[tfms.columns[i]],bins=100)
    plt.title(tfms.columns[i])
